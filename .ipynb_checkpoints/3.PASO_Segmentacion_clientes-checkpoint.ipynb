# %% [markdown]
# ## Este notebook genera la segmentacion ye valuacion de los clientes y hace la matriz de confusion usando el archivo de salida fuente_combinada

# %% [markdown]
# ###### Se importan librerias necesarias

# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
import seaborn as sns
import os
from dateutil.parser import parse
pd.options.display.max_rows = 350
pd.options.display.max_columns = 350
from scipy import stats

# %% [markdown]
# ##### Fuentes consolidada con sector, ventas en la historia

# %%
# %cd D:\MINE\ProyectoFinalMINE\Datos\Fuentes Usadas Tableau\salidas
fuente_combinada = pd.read_excel('fuente_combinada.xlsx')
# Out:
# D:\MINE\ProyectoFinalMINE\Datos\Fuentes Usadas Tableau\salidas

# %%
fuente_combinada.head(2)
# Out:
#                           EMAIL   SubTotal  Numero_facturas ultima_factura  \
# 0  ABOGADOANDRESLOPEZ@GMAIL.COM  1905653.4               14     2017-12-10
# 2         AC.COMPRAS1@GMAIL.COM   408000.0                1     2014-12-24
#
#      TipoUsuario Prioridad    producto         Tipo Cotizacion a enviar  \
# 0  Usuario_Final   3_Media  Sms_Salida  Marcacion_Automatica_CON_Precio
# 2  Usuario_Final    2_Alta  Sms_Salida            SMS_Correo_CON_Precio
#
#   comercial     Fecha creacion                 estado          Sector  \
# 0   mpineda 2015-06-30 08:35:14  en_proceso_Con_Venta       Politicos
# 2   mpineda 2015-10-13 10:23:22               cerrado  SinIdentificar
#
#      ciudad   Periodo  Antiguedad
# 0  Medellin  201506.0        34.0
# 2    Bogota  201510.0        31.0

# %% [markdown]
# ## SELECCIONANDO LAS VARIABLES QUE SE USARAN PARA LA SEGMENTACION

# %%
df_filtro_columnas_para_segmentacion = fuente_combinada[['Prioridad','Tipo Cotizacion a enviar','TipoUsuario','Sector']]

# %%
df_filtro_columnas_para_segmentacion.head(2)
# Out:
#   Prioridad         Tipo Cotizacion a enviar    TipoUsuario          Sector
# 0   3_Media  Marcacion_Automatica_CON_Precio  Usuario_Final       Politicos
# 2    2_Alta            SMS_Correo_CON_Precio  Usuario_Final  SinIdentificar

# %%
# %matplotlib inline

from sklearn import datasets, cluster
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import scale
from sklearn.metrics import confusion_matrix,classification_report

# %% [markdown]
# # Convertir los campos a categoricos

# %%
df_filtro_columnas_para_segmentacion["Prioridad"] = df_filtro_columnas_para_segmentacion["Prioridad"].astype('category')

df_filtro_columnas_para_segmentacion["Tipo Cotizacion a enviar"] = df_filtro_columnas_para_segmentacion["Tipo Cotizacion a enviar"].astype('category')

df_filtro_columnas_para_segmentacion["TipoUsuario"] = df_filtro_columnas_para_segmentacion["TipoUsuario"].astype('category')

df_filtro_columnas_para_segmentacion["Sector"] = df_filtro_columnas_para_segmentacion["Sector"].astype('category')
df_filtro_columnas_para_segmentacion.dtypes
# Out:
# C:\Users\franc\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\franc\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\franc\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\franc\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# Prioridad                   category
# Tipo Cotizacion a enviar    category
# TipoUsuario                 category
# Sector                      category
# dtype: object

# %%
df_filtro_columnas_para_segmentacion["Prioridad"].unique()
# Out:
# [3_Media, 2_Alta, 4_Baja, 1_SuperAlta, NaN]
# Categories (4, object): [3_Media, 2_Alta, 4_Baja, 1_SuperAlta]

# %%
df_filtro_columnas_para_segmentacion["Tipo Cotizacion a enviar"].unique()
# Out:
# [Marcacion_Automatica_CON_Precio, SMS_Correo_CON_Precio, Revendedor_SMS, No_Enviar_Mail, NaN, Hosting, Voip_CON_Precio, SMS_Correo_SIN_Precio]
# Categories (7, object): [Marcacion_Automatica_CON_Precio, SMS_Correo_CON_Precio, Revendedor_SMS, No_Enviar_Mail, Hosting, Voip_CON_Precio, SMS_Correo_SIN_Precio]

# %%
df_filtro_columnas_para_segmentacion["TipoUsuario"].unique()
# Out:
# [Usuario_Final, Revendedor, NaN]
# Categories (2, object): [Usuario_Final, Revendedor]

# %%
df_filtro_columnas_para_segmentacion["Prioridad_cat"] = df_filtro_columnas_para_segmentacion["Prioridad"].cat.codes
df_filtro_columnas_para_segmentacion["Tipo_Cotizacion_a_enviar_cat"] = df_filtro_columnas_para_segmentacion["Tipo Cotizacion a enviar"].cat.codes
df_filtro_columnas_para_segmentacion["TipoUsuario_cat"] = df_filtro_columnas_para_segmentacion["TipoUsuario"].cat.codes
df_filtro_columnas_para_segmentacion["Sector_cat"] = df_filtro_columnas_para_segmentacion["Sector"].cat.codes

df_filtro_columnas_para_segmentacion.head(2)
# Out:
# C:\Users\franc\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\franc\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\franc\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\franc\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#   Prioridad         Tipo Cotizacion a enviar    TipoUsuario          Sector  \
# 0   3_Media  Marcacion_Automatica_CON_Precio  Usuario_Final       Politicos
# 2    2_Alta            SMS_Correo_CON_Precio  Usuario_Final  SinIdentificar
#
#    Prioridad_cat  Tipo_Cotizacion_a_enviar_cat  TipoUsuario_cat  Sector_cat
# 0              2                             1                1          25
# 2              1                             4                1          30

# %%
#del df_filtro_columnas_para_segmentacion["Prioridad"]
#del df_filtro_columnas_para_segmentacion["Tipo Cotizacion a enviar"]
#del df_filtro_columnas_para_segmentacion["TipoUsuario"]
#del df_filtro_columnas_para_segmentacion["SECTOR_FORMATEADO"]

# %%
df_filtro_columnas_para_segmentacion.head(2)
# Out:
#   Prioridad Tipo Cotizacion a enviar    TipoUsuario SECTOR_FORMATEADO  \
# 0    2_Alta    SMS_Correo_CON_Precio  Usuario_Final            Retail
# 1    2_Alta           No_Enviar_Mail  Usuario_Final       Cooperativa
#
#    Prioridad_cat  Tipo_Cotizacion_a_enviar_cat  TipoUsuario_cat  \
# 0              1                             4                1
# 1              1                             2                1
#
#    SECTOR_FORMATEADO_cat
# 0                     27
# 1                     12

# %%
df_tr =df_filtro_columnas_para_segmentacion

#Standardize
clmns = ['Prioridad_cat', 'Tipo_Cotizacion_a_enviar_cat','TipoUsuario_cat', 'SECTOR_FORMATEADO_cat']
df_tr_std = stats.zscore(df_tr[clmns])

#Cluster the data
kmeans = KMeans(n_clusters=4, random_state=0).fit(df_tr_std)
labels = kmeans.labels_

#Glue back to originaal data
df_tr['clusters'] = labels

#Add the column into our list
clmns.extend(['clusters'])

#Lets analyze the clusters
df_tr[clmns].groupby(['clusters']).mean()
# Out:
# C:\Users\franc\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#           Prioridad_cat  Tipo_Cotizacion_a_enviar_cat  TipoUsuario_cat  \
# clusters
# 0              1.500000                      2.956522              0.0
# 1              1.654321                      3.993827              1.0
# 2              1.588235                      1.735294              1.0
# 3              1.656716                      3.940299              1.0
#
#           SECTOR_FORMATEADO_cat
# clusters
# 0                     14.152174
# 1                     30.197531
# 2                     23.941176
# 3                     14.462687

# %%
df_tr.head(100)
# Out:
#       Prioridad         Tipo Cotizacion a enviar    TipoUsuario  \
# 0        2_Alta            SMS_Correo_CON_Precio  Usuario_Final
# 1        2_Alta                   No_Enviar_Mail  Usuario_Final
# 2   1_SuperAlta            SMS_Correo_CON_Precio  Usuario_Final
# 3        4_Baja                   Revendedor_SMS     Revendedor
# 4        4_Baja                   No_Enviar_Mail  Usuario_Final
# 5        4_Baja                   Revendedor_SMS  Usuario_Final
# 6        4_Baja                   No_Enviar_Mail     Revendedor
# 7        4_Baja                   Revendedor_SMS     Revendedor
# 8        4_Baja                   Revendedor_SMS  Usuario_Final
# 9        4_Baja            SMS_Correo_CON_Precio  Usuario_Final
# 10       4_Baja            SMS_Correo_CON_Precio  Usuario_Final
# 11       4_Baja                  Voip_CON_Precio  Usuario_Final
# 12       4_Baja                   Revendedor_SMS     Revendedor
# 13       2_Alta                   No_Enviar_Mail  Usuario_Final
# 14       4_Baja                   No_Enviar_Mail  Usuario_Final
# 15       4_Baja                   Revendedor_SMS     Revendedor
# 16       4_Baja                   Revendedor_SMS  Usuario_Final
# 17       2_Alta                   Revendedor_SMS  Usuario_Final
# 18      3_Media                   No_Enviar_Mail  Usuario_Final
# 19       4_Baja            SMS_Correo_SIN_Precio  Usuario_Final
# 20       4_Baja            SMS_Correo_SIN_Precio  Usuario_Final
# 21      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 22       4_Baja            SMS_Correo_SIN_Precio  Usuario_Final
# 23  1_SuperAlta            SMS_Correo_CON_Precio  Usuario_Final
# 24       2_Alta                   Revendedor_SMS     Revendedor
# 25       2_Alta                   Revendedor_SMS  Usuario_Final
# 26       2_Alta                   Revendedor_SMS  Usuario_Final
# 27       2_Alta                   Revendedor_SMS  Usuario_Final
# 28       2_Alta                   Revendedor_SMS     Revendedor
# 29       4_Baja                   Revendedor_SMS     Revendedor
# 30      3_Media                   Revendedor_SMS     Revendedor
# 31      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 32      3_Media                   No_Enviar_Mail  Usuario_Final
# 33       2_Alta                   Revendedor_SMS  Usuario_Final
# 34       2_Alta            SMS_Correo_CON_Precio  Usuario_Final
# 35       2_Alta            SMS_Correo_CON_Precio  Usuario_Final
# 36  1_SuperAlta                   No_Enviar_Mail     Revendedor
# 37       2_Alta                   Revendedor_SMS  Usuario_Final
# 38       2_Alta                   Revendedor_SMS     Revendedor
# 39       2_Alta                   Revendedor_SMS     Revendedor
# 40       2_Alta  Marcacion_Automatica_CON_Precio  Usuario_Final
# 41  1_SuperAlta            SMS_Correo_CON_Precio  Usuario_Final
# 42      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 43       2_Alta                   Revendedor_SMS     Revendedor
# 44      3_Media  Marcacion_Automatica_CON_Precio  Usuario_Final
# 45       4_Baja            SMS_Correo_CON_Precio  Usuario_Final
# 46      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 47      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 48      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 49      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 50       2_Alta                   Revendedor_SMS  Usuario_Final
# 51      3_Media                   No_Enviar_Mail  Usuario_Final
# 52       2_Alta            SMS_Correo_CON_Precio  Usuario_Final
# 53       4_Baja            SMS_Correo_CON_Precio  Usuario_Final
# 54      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 55       2_Alta            SMS_Correo_CON_Precio  Usuario_Final
# 56       4_Baja            SMS_Correo_CON_Precio  Usuario_Final
# 57      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 58  1_SuperAlta            SMS_Correo_CON_Precio  Usuario_Final
# 59      3_Media            SMS_Correo_SIN_Precio  Usuario_Final
# 60      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 61      3_Media            SMS_Correo_CON_Precio     Revendedor
# 62       2_Alta                   Revendedor_SMS     Revendedor
# 63       2_Alta            SMS_Correo_CON_Precio  Usuario_Final
# 64      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 65       2_Alta                   Revendedor_SMS  Usuario_Final
# 66      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 67      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 68      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 69      3_Media                   No_Enviar_Mail  Usuario_Final
# 70      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 71       2_Alta            SMS_Correo_CON_Precio  Usuario_Final
# 72      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 73      3_Media  Marcacion_Automatica_CON_Precio  Usuario_Final
# 74      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 75      3_Media                   Revendedor_SMS     Revendedor
# 76      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 77       2_Alta  Marcacion_Automatica_CON_Precio  Usuario_Final
# 78      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 79  1_SuperAlta            SMS_Correo_CON_Precio  Usuario_Final
# 80  1_SuperAlta            SMS_Correo_CON_Precio  Usuario_Final
# 81  1_SuperAlta            SMS_Correo_CON_Precio  Usuario_Final
# 82       2_Alta            SMS_Correo_CON_Precio  Usuario_Final
# 83  1_SuperAlta                   Revendedor_SMS  Usuario_Final
# 84      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 85       2_Alta                   Revendedor_SMS     Revendedor
# 86       2_Alta  Marcacion_Automatica_CON_Precio  Usuario_Final
# 87       2_Alta            SMS_Correo_CON_Precio  Usuario_Final
# 88      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 89       2_Alta            SMS_Correo_CON_Precio  Usuario_Final
# 90       4_Baja                   Revendedor_SMS  Usuario_Final
# 91       2_Alta            SMS_Correo_CON_Precio  Usuario_Final
# 92      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 93      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 94      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 95      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 96      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 97       4_Baja            SMS_Correo_CON_Precio  Usuario_Final
# 98      3_Media            SMS_Correo_CON_Precio  Usuario_Final
# 99  1_SuperAlta            SMS_Correo_CON_Precio     Revendedor
#
#        SECTOR_FORMATEADO  Prioridad_cat  Tipo_Cotizacion_a_enviar_cat  \
# 0                 Retail              1                             4
# 1            Cooperativa              1                             2
# 2            Universidad              0                             4
# 3           Distribuidor              3                             3
# 4             Publicidad              3                             2
# 5         SinIdentificar              3                             3
# 6             Callcenter              3                             2
# 7           Distribuidor              3                             3
# 8           Distribuidor              3                             3
# 9          Independiente              3                             4
# 10           Consultoria              3                             4
# 11            Tecnologia              3                             6
# 12          Distribuidor              3                             3
# 13                Retail              1                             2
# 14             Politicos              3                             2
# 15            Tecnologia              3                             3
# 16           Tecnologias              3                             3
# 17          Distribuidor              1                             3
# 18           Universidad              2                             2
# 19        SinIdentificar              3                             5
# 20        SinIdentificar              3                             5
# 21            Publicidad              2                             4
# 22         Independiente              3                             5
# 23           Cooperativa              0                             4
# 24          Distribuidor              1                             3
# 25          Distribuidor              1                             3
# 26             Politicos              1                             3
# 27            Publicidad              1                             3
# 28          Distribuidor              1                             3
# 29          Distribuidor              3                             3
# 30          Distribuidor              2                             3
# 31  InstitutosEducativos              2                             4
# 32            Transporte              2                             2
# 33          Distribuidor              1                             3
# 34     TurismoRecreacion              1                             4
# 35        SinIdentificar              1                             4
# 36           Cooperativa              0                             2
# 37            Callcenter              1                             3
# 38          Distribuidor              1                             3
# 39          Distribuidor              1                             3
# 40        SinIdentificar              1                             1
# 41              Perfumes              0                             4
# 42  InstitutosEducativos              2                             4
# 43          Distribuidor              1                             3
# 44        SinIdentificar              2                             1
# 45               Seguros              3                             4
# 46        SinIdentificar              2                             4
# 47        SinIdentificar              2                             4
# 48               estatal              2                             4
# 49        SinIdentificar              2                             4
# 50            Callcenter              1                             3
# 51         Independiente              2                             2
# 52                 Salud              1                             4
# 53               Casinos              3                             4
# 54     TurismoRecreacion              2                             4
# 55             Politicos              1                             4
# 56        SinIdentificar              3                             4
# 57            Callcenter              2                             4
# 58            Callcenter              0                             4
# 59         Independiente              2                             5
# 60            Callcenter              2                             4
# 61          Distribuidor              2                             4
# 62          Distribuidor              1                             3
# 63          Distribuidor              1                             4
# 64             Fundacion              2                             4
# 65          Distribuidor              1                             3
# 66        SinIdentificar              2                             4
# 67                Retail              2                             4
# 68            Tecnología              2                             4
# 69            Tecnologia              2                             2
# 70                Retail              2                             4
# 71             Marketing              1                             4
# 72                Retail              2                             4
# 73             Politicos              2                             1
# 74             Politicos              2                             4
# 75          Distribuidor              2                             3
# 76               Seguros              2                             4
# 77             Politicos              1                             1
# 78             Auditoria              2                             4
# 79  InstitutosEducativos              0                             4
# 80            Callcenter              0                             4
# 81            Publicidad              0                             4
# 82         Inmobiliarias              1                             4
# 83             Politicos              0                             3
# 84             Fundacion              2                             4
# 85          Distribuidor              1                             3
# 86         Independiente              1                             1
# 87           Cooperativa              1                             4
# 88         Independiente              2                             4
# 89         Independiente              1                             4
# 90         Independiente              3                             3
# 91         Independiente              1                             4
# 92         Independiente              2                             4
# 93           Consultoria              2                             4
# 94           Cooperativa              2                             4
# 95           Consultoria              2                             4
# 96             Marketing              2                             4
# 97         Independiente              3                             4
# 98             Politicos              2                             4
# 99             Politicos              0                             4
#
#     TipoUsuario_cat  SECTOR_FORMATEADO_cat  clusters
# 0                 1                     27         1
# 1                 1                     12         2
# 2                 1                     38         1
# 3                 0                     13         0
# 4                 1                     26         2
# 5                 1                     30         1
# 6                 0                      5         0
# 7                 0                     13         0
# 8                 1                     13         3
# 9                 1                     18         3
# 10                1                     11         3
# 11                1                     31         1
# 12                0                     13         0
# 13                1                     27         2
# 14                1                     25         2
# 15                0                     31         0
# 16                1                     32         1
# 17                1                     13         3
# 18                1                     38         2
# 19                1                     30         1
# 20                1                     30         1
# 21                1                     26         1
# 22                1                     18         3
# 23                1                     12         3
# 24                0                     13         0
# 25                1                     13         3
# 26                1                     25         1
# 27                1                     26         1
# 28                0                     13         0
# 29                0                     13         0
# 30                0                     13         0
# 31                1                     21         3
# 32                1                     36         2
# 33                1                     13         3
# 34                1                     37         1
# 35                1                     30         1
# 36                0                     12         0
# 37                1                      5         3
# 38                0                     13         0
# 39                0                     13         0
# 40                1                     30         2
# 41                1                     24         1
# 42                1                     21         3
# 43                0                     13         0
# 44                1                     30         2
# 45                1                     29         1
# 46                1                     30         1
# 47                1                     30         1
# 48                1                     41         1
# 49                1                     30         1
# 50                1                      5         3
# 51                1                     18         2
# 52                1                     28         1
# 53                1                      7         3
# 54                1                     37         1
# 55                1                     25         1
# 56                1                     30         1
# 57                1                      5         3
# 58                1                      5         3
# 59                1                     18         3
# 60                1                      5         3
# 61                0                     13         0
# 62                0                     13         0
# 63                1                     13         3
# 64                1                     15         3
# 65                1                     13         3
# 66                1                     30         1
# 67                1                     27         1
# 68                1                     33         1
# 69                1                     31         2
# 70                1                     27         1
# 71                1                     23         1
# 72                1                     27         1
# 73                1                     25         2
# 74                1                     25         1
# 75                0                     13         0
# 76                1                     29         1
# 77                1                     25         2
# 78                1                      1         3
# 79                1                     21         3
# 80                1                      5         3
# 81                1                     26         1
# 82                1                     20         3
# 83                1                     25         1
# 84                1                     15         3
# 85                0                     13         0
# 86                1                     18         2
# 87                1                     12         3
# 88                1                     18         3
# 89                1                     18         3
# 90                1                     18         3
# 91                1                     18         3
# 92                1                     18         3
# 93                1                     11         3
# 94                1                     12         3
# 95                1                     11         3
# 96                1                     23         1
# 97                1                     18         3
# 98                1                     25         1
# 99                0                     25         0

# %%
df_tr.groupby('EMAIL')['Estado'].count().reset_index()
